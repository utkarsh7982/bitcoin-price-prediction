# %%
import pandas as pd

# %%
df=pd.read_csv("bitcoin.csv")

# %%
df
# Out:
#                          date         price  total_volume    market_cap  \
# 0     2015-01-01 00:00:00.000    313.992000  4.699936e+07  4.293958e+09
# 1     2015-01-02 00:00:00.000    314.446000  3.885591e+07  4.301448e+09
# 2     2015-01-03 00:00:00.000    286.572000  1.187789e+08  3.921358e+09
# 3     2015-01-04 00:00:00.000    260.936000  2.055001e+08  3.571640e+09
# 4     2015-01-05 00:00:00.000    273.220000  1.550381e+08  3.740880e+09
# ...                       ...           ...           ...           ...
# 3368  2024-03-23 00:00:00.000  63509.044965  4.243660e+10  1.247366e+12
# 3369  2024-03-24 00:00:00.000  64285.802791  2.548993e+10  1.264722e+12
# 3370  2024-03-25 00:00:00.000  67310.983268  2.809832e+10  1.323456e+12
# 3371  2024-03-26 00:00:00.000  69938.945302  4.482031e+10  1.371797e+12
# 3372  2024-03-27 00:00:00.000  70082.051225  3.625732e+10  1.375729e+12
#
#      coin_name
# 0      bitcoin
# 1      bitcoin
# 2      bitcoin
# 3      bitcoin
# 4      bitcoin
# ...

# %%
df = df.drop('date', axis=1)

# %%
df
# Out:
#              price  total_volume    market_cap coin_name
# 0       313.992000  4.699936e+07  4.293958e+09   bitcoin
# 1       314.446000  3.885591e+07  4.301448e+09   bitcoin
# 2       286.572000  1.187789e+08  3.921358e+09   bitcoin
# 3       260.936000  2.055001e+08  3.571640e+09   bitcoin
# 4       273.220000  1.550381e+08  3.740880e+09   bitcoin
# ...            ...           ...           ...       ...
# 3368  63509.044965  4.243660e+10  1.247366e+12   bitcoin
# 3369  64285.802791  2.548993e+10  1.264722e+12   bitcoin
# 3370  67310.983268  2.809832e+10  1.323456e+12   bitcoin
# 3371  69938.945302  4.482031e+10  1.371797e+12   bitcoin
# 3372  70082.051225  3.625732e+10  1.375729e+12   bitcoin
#
# [3373 rows x 4 columns]

# %%
df = df.drop('coin_name', axis=1)

# %%
df
# Out:
#              price  total_volume    market_cap
# 0       313.992000  4.699936e+07  4.293958e+09
# 1       314.446000  3.885591e+07  4.301448e+09
# 2       286.572000  1.187789e+08  3.921358e+09
# 3       260.936000  2.055001e+08  3.571640e+09
# 4       273.220000  1.550381e+08  3.740880e+09
# ...            ...           ...           ...
# 3368  63509.044965  4.243660e+10  1.247366e+12
# 3369  64285.802791  2.548993e+10  1.264722e+12
# 3370  67310.983268  2.809832e+10  1.323456e+12
# 3371  69938.945302  4.482031e+10  1.371797e+12
# 3372  70082.051225  3.625732e+10  1.375729e+12
#
# [3373 rows x 3 columns]

# %%
df.shape
# Out:
# (3373, 3)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3373 entries, 0 to 3372
# Data columns (total 3 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   price         3373 non-null   float64
#  1   total_volume  3373 non-null   float64
#  2   market_cap    3372 non-null   float64
# dtypes: float64(3)
# memory usage: 79.2 KB

# %%
df.head(10)
# Out:
#       price  total_volume    market_cap
# 0  313.9920  4.699936e+07  4.293958e+09
# 1  314.4460  3.885591e+07  4.301448e+09
# 2  286.5720  1.187789e+08  3.921358e+09
# 3  260.9360  2.055001e+08  3.571640e+09
# 4  273.2200  1.550381e+08  3.740880e+09
# 5  285.3738  9.700290e+07  3.908408e+09
# 6  295.8725  1.106742e+08  4.053239e+09
# 7  284.4525  8.657054e+07  3.897824e+09
# 8  289.5738  8.347840e+07  3.968993e+09
# 9  274.5330  9.268384e+07  3.763909e+09

# %%
df.tail(10)
# Out:
#              price  total_volume    market_cap
# 3363  68425.415656  4.719098e+10  1.344509e+12
# 3364  67708.943609  5.110182e+10  1.331772e+12
# 3365  62132.517379  8.017942e+10  1.223867e+12
# 3366  67819.055707  7.083680e+10  1.332594e+12
# 3367  65535.978448  4.839366e+10  1.287348e+12
# 3368  63509.044965  4.243660e+10  1.247366e+12
# 3369  64285.802791  2.548993e+10  1.264722e+12
# 3370  67310.983268  2.809832e+10  1.323456e+12
# 3371  69938.945302  4.482031e+10  1.371797e+12
# 3372  70082.051225  3.625732e+10  1.375729e+12

# %%
df.min()
# Out:
# price           1.721479e+02
# total_volume    1.823845e+07
# market_cap      2.362640e+09
# dtype: float64

# %%
df.max()
# Out:
# price           7.309777e+04
# total_volume    1.788941e+11
# market_cap      1.436631e+12
# dtype: float64

# %%
df.count()
# Out:
# price           3373
# total_volume    3373
# market_cap      3372
# dtype: int64

# %%
df.mean()
# Out:
# price           1.601006e+04
# total_volume    1.724184e+10
# market_cap      3.008013e+11
# dtype: float64

# %%
df.median()
# Out:
# price           8.881392e+03
# total_volume    1.237354e+10
# market_cap      1.583968e+11
# dtype: float64

# %%
df.std()
# Out:
# price           1.719407e+04
# total_volume    1.883256e+10
# market_cap      3.296922e+11
# dtype: float64

# %%
df.count()
# Out:
# price           3373
# total_volume    3373
# market_cap      3372
# dtype: int64

# %%
df.describe()
# Out:
#               price  total_volume    market_cap
# count   3373.000000  3.373000e+03  3.372000e+03
# mean   16010.058094  1.724184e+10  3.008013e+11
# std    17194.074719  1.883256e+10  3.296922e+11
# min      172.147900  1.823845e+07  2.362640e+09
# 25%     1280.986000  1.454057e+09  2.085192e+10
# 50%     8881.391704  1.237354e+10  1.583968e+11
# 75%    26848.239940  2.743276e+10  5.211950e+11
# max    73097.767027  1.788941e+11  1.436631e+12

# %%
df.isnull().sum()
# Out:
# price           0
# total_volume    0
# market_cap      1
# dtype: int64

# %%
# Remove rows where 'market_cap' is NaN
df = df.dropna(subset=['market_cap'])

# %%
df['price'].median()
# Out:
# 8882.541737104431

# %%
df['total_volume'].median()
# Out:
# 12383562973.914062

# %%
df['market_cap'].median()
# Out:
# 158396827885.80847

# %%
import seaborn as sns
sns.boxplot(y = 'price', color = 'r',data = df)
# Out:
# <Axes: ylabel='price'>

# %%
sns.boxplot(y = 'total_volume', color = 'r',data = df)
# Out:
# <Axes: ylabel='total_volume'>

# %%
sns.boxplot(y = 'market_cap', color = 'r',data = df)
# Out:
# <Axes: ylabel='market_cap'>

# %%
df.corr()
# Out:
#                  price  total_volume  market_cap
# price         1.000000      0.659791    0.999506
# total_volume  0.659791      1.000000    0.654636
# market_cap    0.999506      0.654636    1.000000

# %%
import seaborn as sns
sns.heatmap(df.corr(), annot=True)
# Out:
# <Axes: >

# %%
import seaborn as sns
sns.pairplot(df)

# %%
df.columns
# Out:
# Index(['price', 'total_volume', 'market_cap'], dtype='object')

# %%
Y=['price']

# %%
X=[['total_volume', 'market_cap']]

# %%
import pandas as pd
from sklearn.model_selection import train_test_split

# Assuming df is your DataFrame
# Define X and Y correctly
X = df[['total_volume', 'market_cap']]  # Features (predictors)
Y = df['price']                         # Target variable

# Perform the train-test split
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.15, random_state=42)

# Check the shapes of the resulting splits
print(f"X_train shape: {X_train.shape}")
print(f"X_test shape: {X_test.shape}")
print(f"y_train shape: {y_train.shape}")
print(f"y_test shape: {y_test.shape}")
# Out:
# X_train shape: (2866, 2)
# X_test shape: (506, 2)
# y_train shape: (2866,)
# y_test shape: (506,)

# %%
from sklearn.linear_model import LinearRegression
regression = LinearRegression(n_jobs = -1)

# %%
regression.fit(X_train,y_train)
# Out:
# LinearRegression(n_jobs=-1)

# %%
regression
# Out:
# LinearRegression(n_jobs=-1)

# %%
y_pred  = regression.predict(X_test)

# %%
from sklearn.metrics import r2_score
score = r2_score(y_test,y_pred)
print(score)
# Out:
# 0.9989897212277333
